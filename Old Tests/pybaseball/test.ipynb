# %%
from pybaseball import batting_stats, pitching_stats, statcast
import pandas as pd

# Set display options (optional)
pd.set_option("display.max_columns", None)

# %%
# Get batting stats for 2025 season
data = batting_stats(2025)

# Preview the first 10 players
display(data.head(10))
# Out:
#      IDfg  Season                 Name Team  Age   G   AB   PA   H  1B  2B  \
# 0   15640    2025          Aaron Judge  NYY   33  25   94  113  39  24   7
# 4   25878    2025       Corbin Carroll  ARI   24  25  106  119  34  16   8
# 24  27769    2025  Pete Crow-Armstrong  CHC   23  26  102  111  30  15   9
# 7   19709    2025   Fernando Tatis Jr.  SDP   26  24   93  106  31  21   1
# 2   19251    2025          Pete Alonso  NYM   30  25   91  109  31  13  11
# 5   18345    2025          Kyle Tucker  CHC   28  26  102  123  32  15   8
# 10  33824    2025         Jung Hoo Lee  SFG   26  25   96  108  32  16  11
# 6   17929    2025       Cedric Mullins  BAL   30  23   78   97  23  12   5
# 42  25764    2025       Bobby Witt Jr.  KCR   25  26   99  114  30  18  10
# 67  22799    2025      Geraldo Perdomo  ARI   25  25   90  114  23  16   4
#
#     3B  HR   R  RBI  BB  IBB  SO  HBP  SF  SH  GDP  SB  CS    AVG  GB  FB  LD  \
# ...

# %%
data = statcast(start_dt="2025-03-18", end_dt="2025-03-18")
display(data.head(10))
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\Alex\anaconda3\envs\asdf\lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1479        NaN 2025-03-18           <NA>           <NA>           <NA>
# 1517        NaN 2025-03-18           <NA>           <NA>           <NA>
# 1583        NaN 2025-03-18           <NA>           <NA>           <NA>
# 1635        NaN 2025-03-18           <NA>           <NA>           <NA>
# 1719        NaN 2025-03-18           <NA>           <NA>           <NA>
# ...
